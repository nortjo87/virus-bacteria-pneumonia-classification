# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, roc_curve

from jcopml.pipeline import num_pipe, cat_pipe
from jcopml.utils import save_model, load_model
from jcopml.plot import plot_missing_value,plot_confusion_matrix
from jcopml.feature_importance import mean_score_decrease

# from jcopml.plot import

# %%
path = r'virus' # or unix / linux / mac path

# Get the files from the path provided in the OP
files = Path(path).glob('*.csv') # .rglob to get subdirectories

# Read the files into dataframes
dfv = [pd.read_csv(f) for f in files]

# %%
path = r'bakteri' # or unix / linux / mac path

# Get the files from the path provided in the OP
files = Path(path).glob('*.csv') # .rglob to get subdirectories

# Read the files into dataframes
dfb = [pd.read_csv(f) for f in files]

# %%
path = r'kontrol' # or unix / linux / mac path

# Get the files from the path provided in the OP
files = Path(path).glob('*.csv') # .rglob to get subdirectories

# Read the files into dataframes
dfk = [pd.read_csv(f) for f in files]

# %% [markdown]
# Define function

# %%
def mean(series):
    # Find the sum of the Series
    total_sum = series.sum()
    
    # Find the length of the Series
    n = len(series)
    
    # Return the mean
    return total_sum / n

    
import math
def std(data):
    # If data is a pandas Series, convert it to a list
    if isinstance(data, pd.Series):
        data = data.tolist()
    
    # Calculate the mean
    mean = sum(data) / len(data)
    
    # Calculate the sum of squared differences from the mean
    sum_squared_diff = sum((x - mean) ** 2 for x in data)
    
    # Calculate the variance
    variance = sum_squared_diff / len(data)
    
    # Calculate the standard deviation
    std_dev = math.sqrt(variance)
    
    return std_dev

def var(data):
    # If data is a pandas Series, convert it to a list
    if isinstance(data, pd.Series):
        data = data.tolist()
    
    # Calculate the mean
    mean = sum(data) / len(data)
    
    # Calculate the sum of squared differences from the mean
    sum_squared_diff = sum((x - mean) ** 2 for x in data)
    
    # Calculate the sample variance (divide by n - 1 for sample variance)
    sample_variance = sum_squared_diff / (len(data) - 1)
    
    return sample_variance

# %% [markdown]
# Convert

# %%
ndfv=[]
for x in range(len(dfv)):
    a=[
        dfv[x]['S1'][0]-min(dfv[x]['S1']),
        dfv[x]['S2'][0]-min(dfv[x]['S2']),
        dfv[x]['S3'][0]-min(dfv[x]['S3']),
        dfv[x]['S4'][0]-min(dfv[x]['S4']),
        dfv[x]['S5'][0]-min(dfv[x]['S5']),
        dfv[x]['S6'][0]-min(dfv[x]['S6']),
        dfv[x]['S7'][0]-min(dfv[x]['S7']),
        dfv[x]['S8'][0]-min(dfv[x]['S8']),
        dfv[x]['S9'][0]-min(dfv[x]['S9']),
        dfv[x]['S10'][0]-min(dfv[x]['S10'])
    ]
    index=a.index(max(a))
    if (index==0):
        tipe='S1'
    if (index==1):
        tipe='S2'
    if (index==2):
        tipe='S3'
    if (index==3):
        tipe='S4'
    if (index==4):
        tipe='S5'
    if (index==5):
        tipe='S6'
    if (index==6):
        tipe='S7'
    if (index==7):
        tipe='S8'
    if (index==8):
        tipe='S9'
    if (index==9):
        tipe='S10'
        
    penjumlah=dfv[0][tipe]-dfv[0][tipe][0]
    min(penjumlah)
    
    if (min(penjumlah[:651])<-50):
        a=[
            dfv[x]['S1']-penjumlah,
            dfv[x]['S2']-penjumlah,
            dfv[x]['S3']-penjumlah,
            dfv[x]['S4']-penjumlah,
            dfv[x]['S5']-penjumlah,
            dfv[x]['S6']-penjumlah,
            dfv[x]['S7']-penjumlah,
            dfv[x]['S8']-penjumlah,
            dfv[x]['S9']-penjumlah,
            dfv[x]['S10']-penjumlah
        ]
    else:
        a=[
            dfv[x]['S1'],
            dfv[x]['S2'],
            dfv[x]['S3'],
            dfv[x]['S4'],
            dfv[x]['S5'],
            dfv[x]['S6'],
            dfv[x]['S7'],
            dfv[x]['S8'],
            dfv[x]['S9'],
            dfv[x]['S10']
        ]
    
    ndfv.append(a)

# %%
ndfb=[]
for x in range(len(dfb)):
    a=[
        dfb[x]['S1'][0]-min(dfb[x]['S1']),
        dfb[x]['S2'][0]-min(dfb[x]['S2']),
        dfb[x]['S3'][0]-min(dfb[x]['S3']),
        dfb[x]['S4'][0]-min(dfb[x]['S4']),
        dfb[x]['S5'][0]-min(dfb[x]['S5']),
        dfb[x]['S6'][0]-min(dfb[x]['S6']),
        dfb[x]['S7'][0]-min(dfb[x]['S7']),
        dfb[x]['S8'][0]-min(dfb[x]['S8']),
        dfb[x]['S9'][0]-min(dfb[x]['S9']),
        dfb[x]['S10'][0]-min(dfb[x]['S10'])
    ]
    index=a.index(max(a))
    if (index==0):
        tipe='S1'
    if (index==1):
        tipe='S2'
    if (index==2):
        tipe='S3'
    if (index==3):
        tipe='S4'
    if (index==4):
        tipe='S5'
    if (index==5):
        tipe='S6'
    if (index==6):
        tipe='S7'
    if (index==7):
        tipe='S8'
    if (index==8):
        tipe='S9'
    if (index==9):
        tipe='S10'
        
    penjumlah=dfb[0][tipe]-dfb[0][tipe][0]
    min(penjumlah)
    
    if (min(penjumlah[:651])<-50):
        a=[
            dfb[x]['S1']-penjumlah,
            dfb[x]['S2']-penjumlah,
            dfb[x]['S3']-penjumlah,
            dfb[x]['S4']-penjumlah,
            dfb[x]['S5']-penjumlah,
            dfb[x]['S6']-penjumlah,
            dfb[x]['S7']-penjumlah,
            dfb[x]['S8']-penjumlah,
            dfb[x]['S9']-penjumlah,
            dfb[x]['S10']-penjumlah
        ]
    else:
        a=[
            dfb[x]['S1'],
            dfb[x]['S2'],
            dfb[x]['S3'],
            dfb[x]['S4'],
            dfb[x]['S5'],
            dfb[x]['S6'],
            dfb[x]['S7'],
            dfb[x]['S8'],
            dfb[x]['S9'],
            dfb[x]['S10']
        ]
    
    ndfb.append(a)

# %%
ndfk=[]
for x in range(len(dfk)):
    a=[
        dfk[x]['S1'][0]-min(dfk[x]['S1']),
        dfk[x]['S2'][0]-min(dfk[x]['S2']),
        dfk[x]['S3'][0]-min(dfk[x]['S3']),
        dfk[x]['S4'][0]-min(dfk[x]['S4']),
        dfk[x]['S5'][0]-min(dfk[x]['S5']),
        dfk[x]['S6'][0]-min(dfk[x]['S6']),
        dfk[x]['S7'][0]-min(dfk[x]['S7']),
        dfk[x]['S8'][0]-min(dfk[x]['S8']),
        dfk[x]['S9'][0]-min(dfk[x]['S9']),
        dfk[x]['S10'][0]-min(dfk[x]['S10'])
    ]
    index=a.index(max(a))
    if (index==0):
        tipe='S1'
    if (index==1):
        tipe='S2'
    if (index==2):
        tipe='S3'
    if (index==3):
        tipe='S4'
    if (index==4):
        tipe='S5'
    if (index==5):
        tipe='S6'
    if (index==6):
        tipe='S7'
    if (index==7):
        tipe='S8'
    if (index==8):
        tipe='S9'
    if (index==9):
        tipe='S10'
        
    penjumlah=dfk[0][tipe]-dfk[0][tipe][0]
    min(penjumlah)
    
    if (min(penjumlah[:651])<-50):
        a=[
            dfk[x]['S1']-penjumlah,
            dfk[x]['S2']-penjumlah,
            dfk[x]['S3']-penjumlah,
            dfk[x]['S4']-penjumlah,
            dfk[x]['S5']-penjumlah,
            dfk[x]['S6']-penjumlah,
            dfk[x]['S7']-penjumlah,
            dfk[x]['S8']-penjumlah,
            dfk[x]['S9']-penjumlah,
            dfk[x]['S10']-penjumlah
        ]
    else:
        a=[
            dfk[x]['S1'],
            dfk[x]['S2'],
            dfk[x]['S3'],
            dfk[x]['S4'],
            dfk[x]['S5'],
            dfk[x]['S6'],
            dfk[x]['S7'],
            dfk[x]['S8'],
            dfk[x]['S9'],
            dfk[x]['S10']
        ]
    
    ndfk.append(a)

# %% [markdown]
# Max

# %%
dfvMax=[]
for i in range(len(ndfv)):
    x=[]
    # window 1
    maks = max(ndfv[i][0][101:250])
    x.append(maks)
    maks = max(ndfv[i][1][101:250])
    x.append(maks)
    maks = max(ndfv[i][2][101:250])
    x.append(maks)
    maks = max(ndfv[i][3][101:250])
    x.append(maks)
    maks = max(ndfv[i][4][101:250])
    x.append(maks)
    maks = max(ndfv[i][5][101:250])
    x.append(maks)
    maks = max(ndfv[i][6][101:250])
    x.append(maks)
    maks = max(ndfv[i][7][101:250])
    x.append(maks)
    maks = max(ndfv[i][8][101:250])
    x.append(maks)
    maks = max(ndfv[i][9][101:250])
    x.append(maks)
    # window 2
    maks = max(ndfv[i][0][251:650])
    x.append(maks)
    maks = max(ndfv[i][1][251:650])
    x.append(maks)
    maks = max(ndfv[i][2][251:650])
    x.append(maks)
    maks = max(ndfv[i][3][251:650])
    x.append(maks)
    maks = max(ndfv[i][4][251:650])
    x.append(maks)
    maks = max(ndfv[i][5][251:650])
    x.append(maks)
    maks = max(ndfv[i][6][251:650])
    x.append(maks)
    maks = max(ndfv[i][7][251:650])
    x.append(maks)
    maks = max(ndfv[i][8][251:650])
    x.append(maks)
    maks = max(ndfv[i][9][251:650])
    x.append(maks)
    # window 3
    maks = max(ndfv[i][0][651:1500])
    x.append(maks)
    maks = max(ndfv[i][1][651:1500])
    x.append(maks)
    maks = max(ndfv[i][2][651:1500])
    x.append(maks)
    maks = max(ndfv[i][3][651:1500])
    x.append(maks)
    maks = max(ndfv[i][4][651:1500])
    x.append(maks)
    maks = max(ndfv[i][5][651:1500])
    x.append(maks)
    maks = max(ndfv[i][6][651:1500])
    x.append(maks)
    maks = max(ndfv[i][7][651:1500])
    x.append(maks)
    maks = max(ndfv[i][8][651:1500])
    x.append(maks)
    maks = max(ndfv[i][9][651:1500])
    x.append(maks)
    dfvMax.append(x)
    
dfvMax = pd.DataFrame(dfvMax, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfvMax['class']='Virus'
len(dfvMax)
# Out:
# 51

# %%
dfbMax=[]
for i in range(len(ndfb)):
    x=[]
    # window 1
    maks = max(ndfb[i][0][101:250])
    x.append(maks)
    maks = max(ndfb[i][1][101:250])
    x.append(maks)
    maks = max(ndfb[i][2][101:250])
    x.append(maks)
    maks = max(ndfb[i][3][101:250])
    x.append(maks)
    maks = max(ndfb[i][4][101:250])
    x.append(maks)
    maks = max(ndfb[i][5][101:250])
    x.append(maks)
    maks = max(ndfb[i][6][101:250])
    x.append(maks)
    maks = max(ndfb[i][7][101:250])
    x.append(maks)
    maks = max(ndfb[i][8][101:250])
    x.append(maks)
    maks = max(ndfb[i][9][101:250])
    x.append(maks)
    # window 2
    maks = max(ndfb[i][0][251:650])
    x.append(maks)
    maks = max(ndfb[i][1][251:650])
    x.append(maks)
    maks = max(ndfb[i][2][251:650])
    x.append(maks)
    maks = max(ndfb[i][3][251:650])
    x.append(maks)
    maks = max(ndfb[i][4][251:650])
    x.append(maks)
    maks = max(ndfb[i][5][251:650])
    x.append(maks)
    maks = max(ndfb[i][6][251:650])
    x.append(maks)
    maks = max(ndfb[i][7][251:650])
    x.append(maks)
    maks = max(ndfb[i][8][251:650])
    x.append(maks)
    maks = max(ndfb[i][9][251:650])
    x.append(maks)
    # window 3
    maks = max(ndfb[i][0][651:1500])
    x.append(maks)
    maks = max(ndfb[i][1][651:1500])
    x.append(maks)
    maks = max(ndfb[i][2][651:1500])
    x.append(maks)
    maks = max(ndfb[i][3][651:1500])
    x.append(maks)
    maks = max(ndfb[i][4][651:1500])
    x.append(maks)
    maks = max(ndfb[i][5][651:1500])
    x.append(maks)
    maks = max(ndfb[i][6][651:1500])
    x.append(maks)
    maks = max(ndfb[i][7][651:1500])
    x.append(maks)
    maks = max(ndfb[i][8][651:1500])
    x.append(maks)
    maks = max(ndfb[i][9][651:1500])
    x.append(maks)
    dfbMax.append(x)
    
dfbMax = pd.DataFrame(dfbMax, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfbMax['class']='Bakteri'
len(dfbMax)
# Out:
# 153

# %%
dfkMax=[]
for i in range(len(ndfk)):
    x=[]
    # window 1
    maks = max(ndfk[i][0][101:250])
    x.append(maks)
    maks = max(ndfk[i][1][101:250])
    x.append(maks)
    maks = max(ndfk[i][2][101:250])
    x.append(maks)
    maks = max(ndfk[i][3][101:250])
    x.append(maks)
    maks = max(ndfk[i][4][101:250])
    x.append(maks)
    maks = max(ndfk[i][5][101:250])
    x.append(maks)
    maks = max(ndfk[i][6][101:250])
    x.append(maks)
    maks = max(ndfk[i][7][101:250])
    x.append(maks)
    maks = max(ndfk[i][8][101:250])
    x.append(maks)
    maks = max(ndfk[i][9][101:250])
    x.append(maks)
    # window 2
    maks = max(ndfk[i][0][251:650])
    x.append(maks)
    maks = max(ndfk[i][1][251:650])
    x.append(maks)
    maks = max(ndfk[i][2][251:650])
    x.append(maks)
    maks = max(ndfk[i][3][251:650])
    x.append(maks)
    maks = max(ndfk[i][4][251:650])
    x.append(maks)
    maks = max(ndfk[i][5][251:650])
    x.append(maks)
    maks = max(ndfk[i][6][251:650])
    x.append(maks)
    maks = max(ndfk[i][7][251:650])
    x.append(maks)
    maks = max(ndfk[i][8][251:650])
    x.append(maks)
    maks = max(ndfk[i][9][251:650])
    x.append(maks)
    # window 3
    maks = max(ndfk[i][0][651:1500])
    x.append(maks)
    maks = max(ndfk[i][1][651:1500])
    x.append(maks)
    maks = max(ndfk[i][2][651:1500])
    x.append(maks)
    maks = max(ndfk[i][3][651:1500])
    x.append(maks)
    maks = max(ndfk[i][4][651:1500])
    x.append(maks)
    maks = max(ndfk[i][5][651:1500])
    x.append(maks)
    maks = max(ndfk[i][6][651:1500])
    x.append(maks)
    maks = max(ndfk[i][7][651:1500])
    x.append(maks)
    maks = max(ndfk[i][8][651:1500])
    x.append(maks)
    maks = max(ndfk[i][9][651:1500])
    x.append(maks)
    dfkMax.append(x)
    
dfkMax = pd.DataFrame(dfkMax, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfkMax['class']='Kontrol'
len(dfkMax)
# Out:
# 168

# %% [markdown]
# Mean

# %%
dfvMean=[]
for i in range(len(ndfv)):
    x=[]
    # window 1
    means = mean(ndfv[i][0][101:250])
    x.append(means)
    means = mean(ndfv[i][1][101:250])
    x.append(means)
    means = mean(ndfv[i][2][101:250])
    x.append(means)
    means = mean(ndfv[i][3][101:250])
    x.append(means)
    means = mean(ndfv[i][4][101:250])
    x.append(means)
    means = mean(ndfv[i][5][101:250])
    x.append(means)
    means = mean(ndfv[i][6][101:250])
    x.append(means)
    means = mean(ndfv[i][7][101:250])
    x.append(means)
    means = mean(ndfv[i][8][101:250])
    x.append(means)
    means = mean(ndfv[i][9][101:250])
    x.append(means)
    # window 2
    means = mean(ndfv[i][0][251:650])
    x.append(means)
    means = mean(ndfv[i][1][251:650])
    x.append(means)
    means = mean(ndfv[i][2][251:650])
    x.append(means)
    means = mean(ndfv[i][3][251:650])
    x.append(means)
    means = mean(ndfv[i][4][251:650])
    x.append(means)
    means = mean(ndfv[i][5][251:650])
    x.append(means)
    means = mean(ndfv[i][6][251:650])
    x.append(means)
    means = mean(ndfv[i][7][251:650])
    x.append(means)
    means = mean(ndfv[i][8][251:650])
    x.append(means)
    means = mean(ndfv[i][9][251:650])
    x.append(means)
    # window 3
    means = mean(ndfv[i][0][651:1500])
    x.append(means)
    means = mean(ndfv[i][1][651:1500])
    x.append(means)
    means = mean(ndfv[i][2][651:1500])
    x.append(means)
    means = mean(ndfv[i][3][651:1500])
    x.append(means)
    means = mean(ndfv[i][4][651:1500])
    x.append(means)
    means = mean(ndfv[i][5][651:1500])
    x.append(means)
    means = mean(ndfv[i][6][651:1500])
    x.append(means)
    means = mean(ndfv[i][7][651:1500])
    x.append(means)
    means = mean(ndfv[i][8][651:1500])
    x.append(means)
    means = mean(ndfv[i][9][651:1500])
    x.append(means)
    dfvMean.append(x)
    
dfvMean = pd.DataFrame(dfvMean, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfvMean['class']='Virus'
len(dfvMean)
# Out:
# 51

# %%
dfbMean=[]
for i in range(len(ndfb)):
    x=[]
    # window 1
    means = mean(ndfb[i][0][101:250])
    x.append(means)
    means = mean(ndfb[i][1][101:250])
    x.append(means)
    means = mean(ndfb[i][2][101:250])
    x.append(means)
    means = mean(ndfb[i][3][101:250])
    x.append(means)
    means = mean(ndfb[i][4][101:250])
    x.append(means)
    means = mean(ndfb[i][5][101:250])
    x.append(means)
    means = mean(ndfb[i][6][101:250])
    x.append(means)
    means = mean(ndfb[i][7][101:250])
    x.append(means)
    means = mean(ndfb[i][8][101:250])
    x.append(means)
    means = mean(ndfb[i][9][101:250])
    x.append(means)
    # window 2
    means = mean(ndfb[i][0][251:650])
    x.append(means)
    means = mean(ndfb[i][1][251:650])
    x.append(means)
    means = mean(ndfb[i][2][251:650])
    x.append(means)
    means = mean(ndfb[i][3][251:650])
    x.append(means)
    means = mean(ndfb[i][4][251:650])
    x.append(means)
    means = mean(ndfb[i][5][251:650])
    x.append(means)
    means = mean(ndfb[i][6][251:650])
    x.append(means)
    means = mean(ndfb[i][7][251:650])
    x.append(means)
    means = mean(ndfb[i][8][251:650])
    x.append(means)
    means = mean(ndfb[i][9][251:650])
    x.append(means)
    # window 3
    means = mean(ndfb[i][0][651:1500])
    x.append(means)
    means = mean(ndfb[i][1][651:1500])
    x.append(means)
    means = mean(ndfb[i][2][651:1500])
    x.append(means)
    means = mean(ndfb[i][3][651:1500])
    x.append(means)
    means = mean(ndfb[i][4][651:1500])
    x.append(means)
    means = mean(ndfb[i][5][651:1500])
    x.append(means)
    means = mean(ndfb[i][6][651:1500])
    x.append(means)
    means = mean(ndfb[i][7][651:1500])
    x.append(means)
    means = mean(ndfb[i][8][651:1500])
    x.append(means)
    means = mean(ndfb[i][9][651:1500])
    x.append(means)
    dfbMean.append(x)
    
dfbMean = pd.DataFrame(dfbMean, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfbMean['class']='Bakteri'
len(dfbMean)
# Out:
# 153

# %%
dfkMean=[]
for i in range(len(ndfk)):
    x=[]
    # window 1
    means = mean(ndfk[i][0][101:250])
    x.append(means)
    means = mean(ndfk[i][1][101:250])
    x.append(means)
    means = mean(ndfk[i][2][101:250])
    x.append(means)
    means = mean(ndfk[i][3][101:250])
    x.append(means)
    means = mean(ndfk[i][4][101:250])
    x.append(means)
    means = mean(ndfk[i][5][101:250])
    x.append(means)
    means = mean(ndfk[i][6][101:250])
    x.append(means)
    means = mean(ndfk[i][7][101:250])
    x.append(means)
    means = mean(ndfk[i][8][101:250])
    x.append(means)
    means = mean(ndfk[i][9][101:250])
    x.append(means)
    # window 2
    means = mean(ndfk[i][0][251:650])
    x.append(means)
    means = mean(ndfk[i][1][251:650])
    x.append(means)
    means = mean(ndfk[i][2][251:650])
    x.append(means)
    means = mean(ndfk[i][3][251:650])
    x.append(means)
    means = mean(ndfk[i][4][251:650])
    x.append(means)
    means = mean(ndfk[i][5][251:650])
    x.append(means)
    means = mean(ndfk[i][6][251:650])
    x.append(means)
    means = mean(ndfk[i][7][251:650])
    x.append(means)
    means = mean(ndfk[i][8][251:650])
    x.append(means)
    means = mean(ndfk[i][9][251:650])
    x.append(means)
    # window 3
    means = mean(ndfk[i][0][651:1500])
    x.append(means)
    means = mean(ndfk[i][1][651:1500])
    x.append(means)
    means = mean(ndfk[i][2][651:1500])
    x.append(means)
    means = mean(ndfk[i][3][651:1500])
    x.append(means)
    means = mean(ndfk[i][4][651:1500])
    x.append(means)
    means = mean(ndfk[i][5][651:1500])
    x.append(means)
    means = mean(ndfk[i][6][651:1500])
    x.append(means)
    means = mean(ndfk[i][7][651:1500])
    x.append(means)
    means = mean(ndfk[i][8][651:1500])
    x.append(means)
    means = mean(ndfk[i][9][651:1500])
    x.append(means)
    dfkMean.append(x)
    
dfkMean = pd.DataFrame(dfkMean, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfkMean['class']='Kontrol'
len(dfkMean)
# Out:
# 168

# %% [markdown]
# Std

# %%
dfvStd=[]
for i in range(len(ndfv)):
    x=[]
    # window 1
    stds = std(ndfv[i][0][101:250])
    x.append(stds)
    stds = std(ndfv[i][1][101:250])
    x.append(stds)
    stds = std(ndfv[i][2][101:250])
    x.append(stds)
    stds = std(ndfv[i][3][101:250])
    x.append(stds)
    stds = std(ndfv[i][4][101:250])
    x.append(stds)
    stds = std(ndfv[i][5][101:250])
    x.append(stds)
    stds = std(ndfv[i][6][101:250])
    x.append(stds)
    stds = std(ndfv[i][7][101:250])
    x.append(stds)
    stds = std(ndfv[i][8][101:250])
    x.append(stds)
    stds = std(ndfv[i][9][101:250])
    x.append(stds)
    # window 2
    stds = std(ndfv[i][0][251:650])
    x.append(stds)
    stds = std(ndfv[i][1][251:650])
    x.append(stds)
    stds = std(ndfv[i][2][251:650])
    x.append(stds)
    stds = std(ndfv[i][3][251:650])
    x.append(stds)
    stds = std(ndfv[i][4][251:650])
    x.append(stds)
    stds = std(ndfv[i][5][251:650])
    x.append(stds)
    stds = std(ndfv[i][6][251:650])
    x.append(stds)
    stds = std(ndfv[i][7][251:650])
    x.append(stds)
    stds = std(ndfv[i][8][251:650])
    x.append(stds)
    stds = std(ndfv[i][9][251:650])
    x.append(stds)
    # window 3
    stds = std(ndfv[i][0][651:1500])
    x.append(stds)
    stds = std(ndfv[i][1][651:1500])
    x.append(stds)
    stds = std(ndfv[i][2][651:1500])
    x.append(stds)
    stds = std(ndfv[i][3][651:1500])
    x.append(stds)
    stds = std(ndfv[i][4][651:1500])
    x.append(stds)
    stds = std(ndfv[i][5][651:1500])
    x.append(stds)
    stds = std(ndfv[i][6][651:1500])
    x.append(stds)
    stds = std(ndfv[i][7][651:1500])
    x.append(stds)
    stds = std(ndfv[i][8][651:1500])
    x.append(stds)
    stds = std(ndfv[i][9][651:1500])
    x.append(stds)
    dfvStd.append(x)
    
dfvStd = pd.DataFrame(dfvStd, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfvStd['class']='Virus'
len(dfvStd)
# Out:
# 51

# %%
dfbStd=[]
for i in range(len(ndfb)):
    x=[]
    # window 1
    stds = std(ndfb[i][0][101:250])
    x.append(stds)
    stds = std(ndfb[i][1][101:250])
    x.append(stds)
    stds = std(ndfb[i][2][101:250])
    x.append(stds)
    stds = std(ndfb[i][3][101:250])
    x.append(stds)
    stds = std(ndfb[i][4][101:250])
    x.append(stds)
    stds = std(ndfb[i][5][101:250])
    x.append(stds)
    stds = std(ndfb[i][6][101:250])
    x.append(stds)
    stds = std(ndfb[i][7][101:250])
    x.append(stds)
    stds = std(ndfb[i][8][101:250])
    x.append(stds)
    stds = std(ndfb[i][9][101:250])
    x.append(stds)
    # window 2
    stds = std(ndfb[i][0][251:650])
    x.append(stds)
    stds = std(ndfb[i][1][251:650])
    x.append(stds)
    stds = std(ndfb[i][2][251:650])
    x.append(stds)
    stds = std(ndfb[i][3][251:650])
    x.append(stds)
    stds = std(ndfb[i][4][251:650])
    x.append(stds)
    stds = std(ndfb[i][5][251:650])
    x.append(stds)
    stds = std(ndfb[i][6][251:650])
    x.append(stds)
    stds = std(ndfb[i][7][251:650])
    x.append(stds)
    stds = std(ndfb[i][8][251:650])
    x.append(stds)
    stds = std(ndfb[i][9][251:650])
    x.append(stds)
    # window 3
    stds = std(ndfb[i][0][651:1500])
    x.append(stds)
    stds = std(ndfb[i][1][651:1500])
    x.append(stds)
    stds = std(ndfb[i][2][651:1500])
    x.append(stds)
    stds = std(ndfb[i][3][651:1500])
    x.append(stds)
    stds = std(ndfb[i][4][651:1500])
    x.append(stds)
    stds = std(ndfb[i][5][651:1500])
    x.append(stds)
    stds = std(ndfb[i][6][651:1500])
    x.append(stds)
    stds = std(ndfb[i][7][651:1500])
    x.append(stds)
    stds = std(ndfb[i][8][651:1500])
    x.append(stds)
    stds = std(ndfb[i][9][651:1500])
    x.append(stds)
    dfbStd.append(x)
    
dfbStd = pd.DataFrame(dfbStd, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfbStd['class']='Bakteri'
len(dfbStd)
# Out:
# 153

# %%
dfkStd=[]
for i in range(len(ndfk)):
    x=[]
    # window 1
    stds = std(ndfk[i][0][101:250])
    x.append(stds)
    stds = std(ndfk[i][1][101:250])
    x.append(stds)
    stds = std(ndfk[i][2][101:250])
    x.append(stds)
    stds = std(ndfk[i][3][101:250])
    x.append(stds)
    stds = std(ndfk[i][4][101:250])
    x.append(stds)
    stds = std(ndfk[i][5][101:250])
    x.append(stds)
    stds = std(ndfk[i][6][101:250])
    x.append(stds)
    stds = std(ndfk[i][7][101:250])
    x.append(stds)
    stds = std(ndfk[i][8][101:250])
    x.append(stds)
    stds = std(ndfk[i][9][101:250])
    x.append(stds)
    # window 2
    stds = std(ndfk[i][0][251:650])
    x.append(stds)
    stds = std(ndfk[i][1][251:650])
    x.append(stds)
    stds = std(ndfk[i][2][251:650])
    x.append(stds)
    stds = std(ndfk[i][3][251:650])
    x.append(stds)
    stds = std(ndfk[i][4][251:650])
    x.append(stds)
    stds = std(ndfk[i][5][251:650])
    x.append(stds)
    stds = std(ndfk[i][6][251:650])
    x.append(stds)
    stds = std(ndfk[i][7][251:650])
    x.append(stds)
    stds = std(ndfk[i][8][251:650])
    x.append(stds)
    stds = std(ndfk[i][9][251:650])
    x.append(stds)
    # window 3
    stds = std(ndfk[i][0][651:1500])
    x.append(stds)
    stds = std(ndfk[i][1][651:1500])
    x.append(stds)
    stds = std(ndfk[i][2][651:1500])
    x.append(stds)
    stds = std(ndfk[i][3][651:1500])
    x.append(stds)
    stds = std(ndfk[i][4][651:1500])
    x.append(stds)
    stds = std(ndfk[i][5][651:1500])
    x.append(stds)
    stds = std(ndfk[i][6][651:1500])
    x.append(stds)
    stds = std(ndfk[i][7][651:1500])
    x.append(stds)
    stds = std(ndfk[i][8][651:1500])
    x.append(stds)
    stds = std(ndfk[i][9][651:1500])
    x.append(stds)
    dfkStd.append(x)
    
dfkStd = pd.DataFrame(dfkStd, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfkStd['class']='Kontrol'
len(dfkStd)
# Out:
# 168

# %% [markdown]
# Var

# %%
dfvVar=[]
for i in range(len(ndfv)):
    x=[]
    # window 1
    vars = var(ndfv[i][0][101:250])
    x.append(vars)
    vars = var(ndfv[i][1][101:250])
    x.append(vars)
    vars = var(ndfv[i][2][101:250])
    x.append(vars)
    vars = var(ndfv[i][3][101:250])
    x.append(vars)
    vars = var(ndfv[i][4][101:250])
    x.append(vars)
    vars = var(ndfv[i][5][101:250])
    x.append(vars)
    vars = var(ndfv[i][6][101:250])
    x.append(vars)
    vars = var(ndfv[i][7][101:250])
    x.append(vars)
    vars = var(ndfv[i][8][101:250])
    x.append(vars)
    vars = var(ndfv[i][9][101:250])
    x.append(vars)
    # window 2
    vars = var(ndfv[i][0][251:650])
    x.append(vars)
    vars = var(ndfv[i][1][251:650])
    x.append(vars)
    vars = var(ndfv[i][2][251:650])
    x.append(vars)
    vars = var(ndfv[i][3][251:650])
    x.append(vars)
    vars = var(ndfv[i][4][251:650])
    x.append(vars)
    vars = var(ndfv[i][5][251:650])
    x.append(vars)
    vars = var(ndfv[i][6][251:650])
    x.append(vars)
    vars = var(ndfv[i][7][251:650])
    x.append(vars)
    vars = var(ndfv[i][8][251:650])
    x.append(vars)
    vars = var(ndfv[i][9][251:650])
    x.append(vars)
    # window 3
    vars = var(ndfv[i][0][651:1500])
    x.append(vars)
    vars = var(ndfv[i][1][651:1500])
    x.append(vars)
    vars = var(ndfv[i][2][651:1500])
    x.append(vars)
    vars = var(ndfv[i][3][651:1500])
    x.append(vars)
    vars = var(ndfv[i][4][651:1500])
    x.append(vars)
    vars = var(ndfv[i][5][651:1500])
    x.append(vars)
    vars = var(ndfv[i][6][651:1500])
    x.append(vars)
    vars = var(ndfv[i][7][651:1500])
    x.append(vars)
    vars = var(ndfv[i][8][651:1500])
    x.append(vars)
    vars = var(ndfv[i][9][651:1500])
    x.append(vars)
    dfvVar.append(x)
    
dfvVar = pd.DataFrame(dfvVar, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfvVar['class']='Virus'
len(dfvVar)
# Out:
# 51

# %%
dfbVar=[]
for i in range(len(ndfb)):
    x=[]
    # window 1
    vars = var(ndfb[i][0][101:250])
    x.append(vars)
    vars = var(ndfb[i][1][101:250])
    x.append(vars)
    vars = var(ndfb[i][2][101:250])
    x.append(vars)
    vars = var(ndfb[i][3][101:250])
    x.append(vars)
    vars = var(ndfb[i][4][101:250])
    x.append(vars)
    vars = var(ndfb[i][5][101:250])
    x.append(vars)
    vars = var(ndfb[i][6][101:250])
    x.append(vars)
    vars = var(ndfb[i][7][101:250])
    x.append(vars)
    vars = var(ndfb[i][8][101:250])
    x.append(vars)
    vars = var(ndfb[i][9][101:250])
    x.append(vars)
    # window 2
    vars = var(ndfb[i][0][251:650])
    x.append(vars)
    vars = var(ndfb[i][1][251:650])
    x.append(vars)
    vars = var(ndfb[i][2][251:650])
    x.append(vars)
    vars = var(ndfb[i][3][251:650])
    x.append(vars)
    vars = var(ndfb[i][4][251:650])
    x.append(vars)
    vars = var(ndfb[i][5][251:650])
    x.append(vars)
    vars = var(ndfb[i][6][251:650])
    x.append(vars)
    vars = var(ndfb[i][7][251:650])
    x.append(vars)
    vars = var(ndfb[i][8][251:650])
    x.append(vars)
    vars = var(ndfb[i][9][251:650])
    x.append(vars)
    # window 3
    vars = var(ndfb[i][0][651:1500])
    x.append(vars)
    vars = var(ndfb[i][1][651:1500])
    x.append(vars)
    vars = var(ndfb[i][2][651:1500])
    x.append(vars)
    vars = var(ndfb[i][3][651:1500])
    x.append(vars)
    vars = var(ndfb[i][4][651:1500])
    x.append(vars)
    vars = var(ndfb[i][5][651:1500])
    x.append(vars)
    vars = var(ndfb[i][6][651:1500])
    x.append(vars)
    vars = var(ndfb[i][7][651:1500])
    x.append(vars)
    vars = var(ndfb[i][8][651:1500])
    x.append(vars)
    vars = var(ndfb[i][9][651:1500])
    x.append(vars)
    dfbVar.append(x)
    
dfbVar = pd.DataFrame(dfbVar, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfbVar['class']='Bakteri'
len(dfbVar)
# Out:
# 153

# %%
dfkVar=[]
for i in range(len(ndfk)):
    x=[]
    # window 1
    vars = var(ndfk[i][0][101:250])
    x.append(vars)
    vars = var(ndfk[i][1][101:250])
    x.append(vars)
    vars = var(ndfk[i][2][101:250])
    x.append(vars)
    vars = var(ndfk[i][3][101:250])
    x.append(vars)
    vars = var(ndfk[i][4][101:250])
    x.append(vars)
    vars = var(ndfk[i][5][101:250])
    x.append(vars)
    vars = var(ndfk[i][6][101:250])
    x.append(vars)
    vars = var(ndfk[i][7][101:250])
    x.append(vars)
    vars = var(ndfk[i][8][101:250])
    x.append(vars)
    vars = var(ndfk[i][9][101:250])
    x.append(vars)
    # window 2
    vars = var(ndfk[i][0][251:650])
    x.append(vars)
    vars = var(ndfk[i][1][251:650])
    x.append(vars)
    vars = var(ndfk[i][2][251:650])
    x.append(vars)
    vars = var(ndfk[i][3][251:650])
    x.append(vars)
    vars = var(ndfk[i][4][251:650])
    x.append(vars)
    vars = var(ndfk[i][5][251:650])
    x.append(vars)
    vars = var(ndfk[i][6][251:650])
    x.append(vars)
    vars = var(ndfk[i][7][251:650])
    x.append(vars)
    vars = var(ndfk[i][8][251:650])
    x.append(vars)
    vars = var(ndfk[i][9][251:650])
    x.append(vars)
    # window 3
    vars = var(ndfk[i][0][651:1500])
    x.append(vars)
    vars = var(ndfk[i][1][651:1500])
    x.append(vars)
    vars = var(ndfk[i][2][651:1500])
    x.append(vars)
    vars = var(ndfk[i][3][651:1500])
    x.append(vars)
    vars = var(ndfk[i][4][651:1500])
    x.append(vars)
    vars = var(ndfk[i][5][651:1500])
    x.append(vars)
    vars = var(ndfk[i][6][651:1500])
    x.append(vars)
    vars = var(ndfk[i][7][651:1500])
    x.append(vars)
    vars = var(ndfk[i][8][651:1500])
    x.append(vars)
    vars = var(ndfk[i][9][651:1500])
    x.append(vars)
    dfkVar.append(x)
    
dfkVar = pd.DataFrame(dfkVar, columns=["s1w1", "s2w1",'s3w1','s4w1','s5w1','s6w1','s7w1','s8w1','s9w1','s10w1',"s1w2", "s2w2",'s3w2','s4w2','s5w2','s6w2','s7w2','s8w2','s9w2','s10w2',"s1w3", "s2w3",'s3w3','s4w3','s5w3','s6w3','s7w3','s8w3','s9w3','s10w3'])
dfkVar['class']='Kontrol'
len(dfkVar)
# Out:
# 168

# %%
# maximum VBK
dfbMax['class']=1
dfvMax['class']=2
dfkMax['class']=3
dfVBKMax=pd.concat([dfbMax,dfvMax,dfkMax],axis=0)
dfVBKMax.reset_index(drop=True, inplace=True)
# maximum VB
dfbMax['class']=0
dfvMax['class']=1
dfVBMax=pd.concat([dfbMax,dfvMax],axis=0)
dfVBMax.reset_index(drop=True, inplace=True)
# maximum PK
dfbMax['class']=0
dfvMax['class']=0
dfkMax['class']=1
dfPKMax=pd.concat([dfbMax,dfvMax,dfkMax],axis=0)
dfPKMax.reset_index(drop=True, inplace=True)

# Mean VBK
dfbMean['class']=1
dfvMean['class']=2
dfkMean['class']=3
dfVBKMean=pd.concat([dfbMean,dfvMean,dfkMean],axis=0)
dfVBKMean.reset_index(drop=True, inplace=True)
# Mean VB
dfbMean['class']=0
dfvMean['class']=1
dfVBMean=pd.concat([dfbMean,dfvMean],axis=0)
dfVBMean.reset_index(drop=True, inplace=True)
# Mean PK
dfbMean['class']=0
dfvMean['class']=0
dfkMean['class']=1
dfPKMean=pd.concat([dfbMean,dfvMean,dfkMean],axis=0)
dfPKMean.reset_index(drop=True, inplace=True)

# Stdimum VBK
dfbStd['class']=1
dfvStd['class']=2
dfkStd['class']=3
dfVBKStd=pd.concat([dfbStd,dfvStd,dfkStd],axis=0)
dfVBKStd.reset_index(drop=True, inplace=True)
# Stdimum VB
dfbStd['class']=0
dfvStd['class']=1
dfVBStd=pd.concat([dfbStd,dfvStd],axis=0)
dfVBStd.reset_index(drop=True, inplace=True)
# Stdimum PK
dfbStd['class']=0
dfvStd['class']=0
dfkStd['class']=1
dfPKStd=pd.concat([dfbStd,dfvStd,dfkStd],axis=0)
dfPKStd.reset_index(drop=True, inplace=True)

# Varimum VBK
dfbVar['class']=1
dfvVar['class']=2
dfkVar['class']=3
dfVBKVar=pd.concat([dfbVar,dfvVar,dfkVar],axis=0)
dfVBKVar.reset_index(drop=True, inplace=True)
# Varimum VB
dfbVar['class']=0
dfvVar['class']=1
dfVBVar=pd.concat([dfbVar,dfvVar],axis=0)
dfVBVar.reset_index(drop=True, inplace=True)
# Varimum PK
dfbVar['class']=0
dfvVar['class']=0
dfkVar['class']=1
dfPKVar=pd.concat([dfbVar,dfvVar,dfkVar],axis=0)
dfPKVar.reset_index(drop=True, inplace=True)

# %% [markdown]
# All

# %%
# Rename the feature columns in each DataFrame to make them unique
dfVBVar_renamed = dfVBVar.rename(columns=lambda x: f'{x}_var' if x != 'class' else x)
dfVBMax_renamed = dfVBMax.rename(columns=lambda x: f'{x}_max' if x != 'class' else x)
dfVBMean_renamed = dfVBMean.rename(columns=lambda x: f'{x}_med' if x != 'class' else x)
dfVBStd_renamed = dfVBStd.rename(columns=lambda x: f'{x}_std' if x != 'class' else x)

# Drop the 'class' column from the other DataFrames except one (we'll keep dfVBVar's class)
dfVBMax_renamed = dfVBMax_renamed.drop(columns=['class'])
dfVBMean_renamed = dfVBMean_renamed.drop(columns=['class'])
dfVBStd_renamed = dfVBStd_renamed.drop(columns=['class'])

# Concatenate the DataFrames column-wise
dfVBAll = pd.concat([dfVBVar_renamed, dfVBMax_renamed, dfVBMean_renamed, dfVBStd_renamed], axis=1)
dfVBAll.reset_index(drop=True, inplace=True)

# Rename the feature columns in each DataFrame to make them unique
dfVBKVar_renamed = dfVBKVar.rename(columns=lambda x: f'{x}_var' if x != 'class' else x)
dfVBKMax_renamed = dfVBKMax.rename(columns=lambda x: f'{x}_max' if x != 'class' else x)
dfVBKMean_renamed = dfVBKMean.rename(columns=lambda x: f'{x}_med' if x != 'class' else x)
dfVBKStd_renamed = dfVBKStd.rename(columns=lambda x: f'{x}_std' if x != 'class' else x)

# Drop the 'class' column from the other DataFrames except one (we'll keep dfVBKVar's class)
dfVBKMax_renamed = dfVBKMax_renamed.drop(columns=['class'])
dfVBKMean_renamed = dfVBKMean_renamed.drop(columns=['class'])
dfVBKStd_renamed = dfVBKStd_renamed.drop(columns=['class'])

# Concatenate the DataFrames column-wise
dfVBKAll = pd.concat([dfVBKVar_renamed, dfVBKMax_renamed, dfVBKMean_renamed, dfVBKStd_renamed], axis=1)
dfVBKAll.reset_index(drop=True, inplace=True)

# Rename the feature columns in each DataFrame to make them unique
dfPKVar_renamed = dfPKVar.rename(columns=lambda x: f'{x}_var' if x != 'class' else x)
dfPKMax_renamed = dfPKMax.rename(columns=lambda x: f'{x}_max' if x != 'class' else x)
dfPKMean_renamed = dfPKMean.rename(columns=lambda x: f'{x}_med' if x != 'class' else x)
dfPKStd_renamed = dfPKStd.rename(columns=lambda x: f'{x}_std' if x != 'class' else x)

# Drop the 'class' column from the other DataFrames except one (we'll keep dfPKVar's class)
dfPKMax_renamed = dfPKMax_renamed.drop(columns=['class'])
dfPKMean_renamed = dfPKMean_renamed.drop(columns=['class'])
dfPKStd_renamed = dfPKStd_renamed.drop(columns=['class'])

# Concatenate the DataFrames column-wise
dfPKAll = pd.concat([dfPKVar_renamed, dfPKMax_renamed, dfPKMean_renamed, dfPKStd_renamed], axis=1)
dfPKAll.reset_index(drop=True, inplace=True)

# %% [markdown]
# IQR Plot

# %%
import seaborn as sns

# Max
data_long = pd.melt(dfVBKMax, id_vars='class', var_name='Sensor', value_name='Maximum Value (mV)')

sns.boxplot(y='Maximum Value (mV)', x='Sensor', hue='class', data=data_long)
# Out:
# <AxesSubplot:xlabel='Sensor', ylabel='Maximum Value (mV)'>

# %%
# Max
data_long = pd.melt(dfVBKMean, id_vars='class', var_name='Sensor', value_name='Mean Value (mV)')

sns.boxplot(y='Mean Value (mV)', x='Sensor', hue='class', data=data_long)
# Out:
# <AxesSubplot:xlabel='Sensor', ylabel='Mean Value (mV)'>

# %%
# MStdax
data_long = pd.melt(dfVBKStd, id_vars='class', var_name='Sensor', value_name='Standar Deviasi Value (mV)')

sns.boxplot(y='Standar Deviasi Value (mV)', x='Sensor', hue='class', data=data_long)
# Out:
# <AxesSubplot:xlabel='Sensor', ylabel='Standar Deviasi Value (mV)'>

# %%
# Var
data_long = pd.melt(dfVBKVar, id_vars='class', var_name='Sensor', value_name='Variasi Value (mV)')

sns.boxplot(y='Variasi Value (mV)', x='Sensor', hue='class', data=data_long)
# Out:
# <AxesSubplot:xlabel='Sensor', ylabel='Variasi Value (mV)'>

# %% [markdown]
# IQR remove outliers

# %%
# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBMax['class']
df_features = dfVBMax.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBMax = pd.concat([df_features, class_column], axis=1)

# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBMean['class']
df_features = dfVBMean.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBMean = pd.concat([df_features, class_column], axis=1)

# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBStd['class']
df_features = dfVBStd.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBStd = pd.concat([df_features, class_column], axis=1)


# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBVar['class']
df_features = dfVBVar.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBVar = pd.concat([df_features, class_column], axis=1)


# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBAll['class']
df_features = dfVBAll.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBAll = pd.concat([df_features, class_column], axis=1)

# %%
# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBKMax['class']
df_features = dfVBKMax.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBKMax = pd.concat([df_features, class_column], axis=1)

# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBKMean['class']
df_features = dfVBKMean.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBKMean = pd.concat([df_features, class_column], axis=1)

# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBKStd['class']
df_features = dfVBKStd.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBKStd = pd.concat([df_features, class_column], axis=1)


# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBKVar['class']
df_features = dfVBKVar.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBKVar = pd.concat([df_features, class_column], axis=1)


# Memisahkan kolom 'class' dari DataFrame
class_column = dfVBKAll['class']
df_features = dfVBKAll.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfVBKAll = pd.concat([df_features, class_column], axis=1)

# %%
# Memisahkan kolom 'class' dari DataFrame
class_column = dfPKMax['class']
df_features = dfPKMax.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfPKMax = pd.concat([df_features, class_column], axis=1)

# Memisahkan kolom 'class' dari DataFrame
class_column = dfPKMean['class']
df_features = dfPKMean.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfPKMean = pd.concat([df_features, class_column], axis=1)

# Memisahkan kolom 'class' dari DataFrame
class_column = dfPKStd['class']
df_features = dfPKStd.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfPKStd = pd.concat([df_features, class_column], axis=1)


# Memisahkan kolom 'class' dari DataFrame
class_column = dfPKVar['class']
df_features = dfPKVar.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfPKVar = pd.concat([df_features, class_column], axis=1)


# Memisahkan kolom 'class' dari DataFrame
class_column = dfPKAll['class']
df_features = dfPKAll.drop('class', axis=1)

# Menghitung Q1, Q3, dan IQR untuk setiap fitur
Q1 = df_features.quantile(0.25)
Q3 = df_features.quantile(0.75)
IQR = Q3 - Q1

# Menentukan lower bound dan upper bound
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Fungsi untuk mengganti outliers
def replace_outliers(column, lower, upper):
    column = column.copy()
    column[column < lower] = lower
    column[column > upper] = upper
    return column

# Mengganti outliers di setiap fitur kecuali 'class'
for feature in df_features.columns:
    df_features[feature] = replace_outliers(df_features[feature], lower_bound[feature], upper_bound[feature])

# Menggabungkan kembali fitur dengan kolom 'class'
dfPKAll = pd.concat([df_features, class_column], axis=1)

# %% [markdown]
# Oversampling

# %%
from imblearn.over_sampling import SMOTE

# Memisahkan fitur dan class
X = dfVBMax.drop('class', axis=1)
y = dfVBMax['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBMaxSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBMean.drop('class', axis=1)
y = dfVBMean['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBMeanSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBVar.drop('class', axis=1)
y = dfVBVar['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBVarSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBStd.drop('class', axis=1)
y = dfVBStd['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBStdSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBAll.drop('class', axis=1)
y = dfVBAll['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBAllSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# %%
from imblearn.over_sampling import SMOTE

# Memisahkan fitur dan class
X = dfVBKMax.drop('class', axis=1)
y = dfVBKMax['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKMaxSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBKMean.drop('class', axis=1)
y = dfVBKMean['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKMeanSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBKVar.drop('class', axis=1)
y = dfVBKVar['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKVarSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBKStd.drop('class', axis=1)
y = dfVBKStd['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKStdSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBKAll.drop('class', axis=1)
y = dfVBKAll['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKAllSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# %%
from imblearn.over_sampling import SMOTE

# Memisahkan fitur dan class
X = dfPKMax.drop('class', axis=1)
y = dfPKMax['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKMaxSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfPKMean.drop('class', axis=1)
y = dfPKMean['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKMeanSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfPKVar.drop('class', axis=1)
y = dfPKVar['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKVarSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfPKStd.drop('class', axis=1)
y = dfPKStd['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKStdSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfPKAll.drop('class', axis=1)
y = dfPKAll['class']

# Melakukan oversampling dengan SMOTE
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKAllSmote = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# %% [markdown]
# ADASYN

# %%
from imblearn.over_sampling import ADASYN

# Memisahkan fitur dan class
X = dfVBMax.drop('class', axis=1)
y = dfVBMax['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBMaxAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBMean.drop('class', axis=1)
y = dfVBMean['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBMeanAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBVar.drop('class', axis=1)
y = dfVBVar['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBVarAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBStd.drop('class', axis=1)
y = dfVBStd['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBStdAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBAll.drop('class', axis=1)
y = dfVBAll['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBAllAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# %%
from imblearn.over_sampling import ADASYN

# Memisahkan fitur dan class
X = dfPKMax.drop('class', axis=1)
y = dfPKMax['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKMaxAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfPKMean.drop('class', axis=1)
y = dfPKMean['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKMeanAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfPKVar.drop('class', axis=1)
y = dfPKVar['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKVarAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfPKStd.drop('class', axis=1)
y = dfPKStd['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKStdAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfPKAll.drop('class', axis=1)
y = dfPKAll['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42)
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfPKAllAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# %%
from imblearn.over_sampling import ADASYN

# Memisahkan fitur dan class
X = dfVBKMax.drop('class', axis=1)
y = dfVBKMax['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42,sampling_strategy='minority')
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKMaxAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBKMean.drop('class', axis=1)
y = dfVBKMean['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42,sampling_strategy='minority')
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKMeanAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBKVar.drop('class', axis=1)
y = dfVBKVar['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42,sampling_strategy='minority')
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKVarAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBKStd.drop('class', axis=1)
y = dfVBKStd['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42,sampling_strategy='minority')
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKStdAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# Memisahkan fitur dan class
X = dfVBKAll.drop('class', axis=1)
y = dfVBKAll['class']

# Melakukan oversampling dengan adasyn
adasyn = ADASYN(random_state=42,sampling_strategy='minority')
X_resampled, y_resampled = adasyn.fit_resample(X, y)

# Mengonversi hasil kembali ke DataFrame
X_resampled_df = pd.DataFrame(X_resampled, columns=X.columns)
y_resampled_df = pd.DataFrame(y_resampled, columns=['class'])

# Menggabungkan kembali fitur dan class
dfVBKAllAdasyn = pd.concat([X_resampled_df, y_resampled_df], axis=1)

# %% [markdown]
# Chosse best Parameter in smoothe and adasyn and Fe

# %% [markdown]
# SMote

# %%
import pandas as pd

def evaluate(model, X_train, y_train, X_test, y_test):
    # Print parameter terbaik
    print(model.best_params_)
    
    # Print skor model
    print('Accuracy train:',model.score(X_train, y_train))
    print('Accuracy test:',model.score(X_test, y_test))
    
    
    # Mengakses hasil pencarian
    cv_results = model.cv_results_
    
    # Mendapatkan parameter terbaik
    best_params = model.best_params_
    print(f"Best parameters: {best_params}")
    
    # Mengonversi cv_results_ menjadi DataFrame untuk memudahkan analisis
    results_df = pd.DataFrame(cv_results)
    
    # Menemukan indeks dari parameter terbaik
    best_index = results_df['params'].tolist().index(best_params)
    
    # Menampilkan hasil 10 fold untuk parameter terbaik
    best_fold_results = results_df.iloc[best_index][[
        'split0_test_score', 'split1_test_score', 'split2_test_score',
        'split3_test_score', 'split4_test_score', 'split5_test_score',
        'split6_test_score', 'split7_test_score', 'split8_test_score',
        'split9_test_score'
    ]]
    
    # Buat DataFrame dari best_fold_results
    best_fold_results_df = pd.DataFrame(best_fold_results)
    
    # Hitung nilai rata-rata
    mean_value = best_fold_results_df.mean()
    
    # Hitung standar deviasi
    std_deviation = best_fold_results_df.std()
    
    # Print hasil
    print('10 fold accuracy:')
    print(pd.DataFrame(best_fold_results))
    print("Mean CV:", mean_value)
    print("Std CV:", std_deviation)

# Contoh pemanggilan fungsi
# print_grid_search_results(model, X_train, y_train, X_test, y_test)

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKMaxSmote.drop('class', axis=1)
y = dfPKMaxSmote['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKMaxSmote.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK Max Smote.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7791411042944786
# Accuracy test: 0.6707317073170732
# Best parameters: {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                           8
# split0_test_score  0.727273
# split1_test_score  0.787879
# split2_test_score  0.666667
# split3_test_score  0.757576
# split4_test_score  0.818182
# split5_test_score  0.636364
# split6_test_score   0.71875
# split7_test_score    0.6875
# split8_test_score   0.78125
# split9_test_score     0.875
# Mean CV: 8    0.745644
# dtype: object
# Std CV: 8    0.072885
# dtype: object
# Model is pickled as model/try LDA PK Max Smote.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.70852273 0.70852273 0.70852273 0.70852273 0.70852273 0.70852273
#         nan        nan 0.74564394 0.74564394 0.74564394 0.74564394
#         nan        nan 0.73352273 0.73352273 0.73352273 0.73352273
#         nan        nan 0.71193182 0.71193182 0.71193182 0.71193182
#         nan        nan 0.70265152 0.70265152 0.70265152 0.70265152
#         nan        nan 0.70587121 0.70587121 0.70587121 0.70587121
#         nan        nan 0.70899621 0.70899621 0.70899621 0.70899621
#         nan        nan 0.70909091 0.70909091 0.70909091 0.70909091
#         nan        nan 0.71193182 0.71193182 0.71193182 0.71193182
#         nan        nan 0.6811553  0.6811553  0.6811553  0.6811553
#         nan        nan 0.67793561 0.67793561 0.67793561 0.67793561]
#   warnings.warn(

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKMeanSmote.drop('class', axis=1)
y = dfPKMeanSmote['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKMeanSmote.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK Mean Smote.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7944785276073619
# Accuracy test: 0.7317073170731707
# Best parameters: {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                           8
# split0_test_score  0.727273
# split1_test_score  0.818182
# split2_test_score  0.787879
# split3_test_score  0.757576
# split4_test_score  0.787879
# split5_test_score  0.757576
# split6_test_score    0.6875
# split7_test_score   0.65625
# split8_test_score      0.75
# split9_test_score     0.875
# Mean CV: 8    0.760511
# dtype: object
# Std CV: 8    0.062685
# dtype: object
# Model is pickled as model/try LDA PK Mean Smote.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.73323864 0.73323864 0.73323864 0.73323864 0.73323864 0.73323864
#         nan        nan 0.76051136 0.76051136 0.76051136 0.76051136
#         nan        nan 0.73323864 0.73323864 0.73323864 0.73323864
#         nan        nan 0.73314394 0.73314394 0.73314394 0.73314394
#         nan        nan 0.72689394 0.72689394 0.72689394 0.72689394
#         nan        nan 0.72698864 0.72698864 0.72698864 0.72698864
#         nan        nan 0.72092803 0.72092803 0.72092803 0.72092803
#         nan        nan 0.71174242 0.71174242 0.71174242 0.71174242
#         nan        nan 0.70265152 0.70265152 0.70265152 0.70265152
#         nan        nan 0.70568182 0.70568182 0.70568182 0.70568182
#         nan        nan 0.68380682 0.68380682 0.68380682 0.68380682]
#   warnings.warn(

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKStdSmote.drop('class', axis=1)
y = dfPKStdSmote['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKStdSmote.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK Std Smote.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 0.1, 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7607361963190185
# Accuracy test: 0.6585365853658537
# Best parameters: {'lda__shrinkage': 0.1, 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                          14
# split0_test_score  0.666667
# split1_test_score  0.727273
# split2_test_score  0.727273
# split3_test_score  0.757576
# split4_test_score  0.727273
# split5_test_score  0.666667
# split6_test_score   0.78125
# split7_test_score    0.6875
# split8_test_score   0.78125
# split9_test_score   0.84375
# Mean CV: 14    0.736648
# dtype: object
# Std CV: 14    0.056136
# dtype: object
# Model is pickled as model/try LDA PK Std Smote.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.73352273 0.73352273 0.73352273 0.73352273 0.73352273 0.73352273
#         nan        nan 0.71534091 0.71534091 0.71534091 0.71534091
#         nan        nan 0.73664773 0.73664773 0.73664773 0.73664773
#         nan        nan 0.72755682 0.72755682 0.72755682 0.72755682
#         nan        nan 0.73039773 0.73039773 0.73039773 0.73039773
#         nan        nan 0.71496212 0.71496212 0.71496212 0.71496212
#         nan        nan 0.70577652 0.70577652 0.70577652 0.70577652
#         nan        nan 0.70274621 0.70274621 0.70274621 0.70274621
#         nan        nan 0.69659091 0.69659091 0.69659091 0.69659091
#         nan        nan 0.67784091 0.67784091 0.67784091 0.67784091
#         nan        nan 0.659375   0.659375   0.659375   0.659375  ]
#   warnings.warn(

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKVarSmote.drop('class', axis=1)
y = dfPKVarSmote['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKVarSmote.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK Var Smote.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7239263803680982
# Accuracy test: 0.6219512195121951
# Best parameters: {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                           8
# split0_test_score  0.606061
# split1_test_score  0.666667
# split2_test_score  0.787879
# split3_test_score  0.727273
# split4_test_score   0.69697
# split5_test_score  0.666667
# split6_test_score      0.75
# split7_test_score    0.6875
# split8_test_score   0.78125
# split9_test_score      0.75
# Mean CV: 8    0.712027
# dtype: object
# Std CV: 8    0.057575
# dtype: object
# Model is pickled as model/try LDA PK Var Smote.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.67244318 0.67244318 0.67244318 0.67244318 0.67244318 0.67244318
#         nan        nan 0.71202652 0.71202652 0.71202652 0.71202652
#         nan        nan 0.68721591 0.68721591 0.68721591 0.68721591
#         nan        nan 0.65340909 0.65340909 0.65340909 0.65340909
#         nan        nan 0.65331439 0.65331439 0.65331439 0.65331439
#         nan        nan 0.6592803  0.6592803  0.6592803  0.6592803
#         nan        nan 0.65293561 0.65293561 0.65293561 0.65293561
#         nan        nan 0.6467803  0.6467803  0.6467803  0.6467803
#         nan        nan 0.6469697  0.6469697  0.6469697  0.6469697
#         nan        nan 0.6469697  0.6469697  0.6469697  0.6469697
#         nan        nan 0.64393939 0.64393939 0.64393939 0.64393939]
#   warnings.warn(

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKAllSmote.drop('class', axis=1)
y = dfPKAllSmote['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKAllSmote.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK All Smote.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7484662576687117
# Accuracy test: 0.7073170731707317
# Best parameters: {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                           8
# split0_test_score  0.606061
# split1_test_score   0.69697
# split2_test_score  0.787879
# split3_test_score  0.666667
# split4_test_score  0.757576
# split5_test_score  0.606061
# split6_test_score      0.75
# split7_test_score   0.65625
# split8_test_score   0.71875
# split9_test_score     0.875
# Mean CV: 8    0.712121
# dtype: object
# Std CV: 8    0.084148
# dtype: object
# Model is pickled as model/try LDA PK All Smote.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.71174242 0.71174242 0.71174242 0.71174242 0.71174242 0.71174242
#         nan        nan 0.71212121 0.71212121 0.71212121 0.71212121
#         nan        nan 0.6999053  0.6999053  0.6999053  0.6999053
#         nan        nan 0.6905303  0.6905303  0.6905303  0.6905303
#         nan        nan 0.69043561 0.69043561 0.69043561 0.69043561
#         nan        nan 0.6874053  0.6874053  0.6874053  0.6874053
#         nan        nan 0.69043561 0.69043561 0.69043561 0.69043561
#         nan        nan 0.69024621 0.69024621 0.69024621 0.69024621
#         nan        nan 0.70558712 0.70558712 0.70558712 0.70558712
#         nan        nan 0.70236742 0.70236742 0.70236742 0.70236742
#         nan        nan 0.69005682 0.69005682 0.69005682 0.69005682]
#   warnings.warn(

# %% [markdown]
# Adasyn

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKMaxAdasyn.drop('class', axis=1)
y = dfPKMaxAdasyn['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKMaxAdasyn.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK Max Adasyn.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7641196013289037
# Accuracy test: 0.6973684210526315
# Best parameters: {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                           8
# split0_test_score  0.806452
# split1_test_score       0.7
# split2_test_score  0.633333
# split3_test_score       0.7
# split4_test_score  0.633333
# split5_test_score  0.766667
# split6_test_score  0.633333
# split7_test_score       0.8
# split8_test_score  0.766667
# split9_test_score       0.8
# Mean CV: 8    0.723978
# dtype: object
# Std CV: 8    0.072881
# dtype: object
# Model is pickled as model/try LDA PK Max Adasyn.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.70731183 0.70731183 0.70731183 0.70731183 0.70731183 0.70731183
#         nan        nan 0.72397849 0.72397849 0.72397849 0.72397849
#         nan        nan 0.70741935 0.70741935 0.70741935 0.70741935
#         nan        nan 0.71086022 0.71086022 0.71086022 0.71086022
#         nan        nan 0.70752688 0.70752688 0.70752688 0.70752688
#         nan        nan 0.69752688 0.69752688 0.69752688 0.69752688
#         nan        nan 0.69741935 0.69741935 0.69741935 0.69741935
#         nan        nan 0.69397849 0.69397849 0.69397849 0.69397849
#         nan        nan 0.68741935 0.68741935 0.68741935 0.68741935
#         nan        nan 0.69408602 0.69408602 0.69408602 0.69408602
#         nan        nan 0.67741935 0.67741935 0.67741935 0.67741935]
#   warnings.warn(

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKMeanAdasyn.drop('class', axis=1)
y = dfPKMeanAdasyn['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKMeanAdasyn.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK Mean Adasyn.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': None, 'lda__solver': 'svd', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7954545454545454
# Accuracy test: 0.7142857142857143
# Best parameters: {'lda__shrinkage': None, 'lda__solver': 'svd', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                           0
# split0_test_score  0.774194
# split1_test_score  0.806452
# split2_test_score  0.677419
# split3_test_score  0.677419
# split4_test_score  0.774194
# split5_test_score  0.806452
# split6_test_score  0.741935
# split7_test_score  0.709677
# split8_test_score       0.8
# split9_test_score       0.7
# Mean CV: 0    0.746774
# dtype: object
# Std CV: 0    0.052352
# dtype: object
# Model is pickled as model/try LDA PK Mean Adasyn.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.74677419 0.74677419 0.74677419 0.74677419 0.74677419 0.74677419
#         nan        nan 0.73387097 0.73387097 0.73387097 0.73387097
#         nan        nan 0.74354839 0.74354839 0.74354839 0.74354839
#         nan        nan 0.74376344 0.74376344 0.74376344 0.74376344
#         nan        nan 0.73387097 0.73387097 0.73387097 0.73387097
#         nan        nan 0.72086022 0.72086022 0.72086022 0.72086022
#         nan        nan 0.7144086  0.7144086  0.7144086  0.7144086
#         nan        nan 0.71107527 0.71107527 0.71107527 0.71107527
#         nan        nan 0.70462366 0.70462366 0.70462366 0.70462366
#         nan        nan 0.69817204 0.69817204 0.69817204 0.69817204
#         nan        nan 0.67215054 0.67215054 0.67215054 0.67215054]
#   warnings.warn(

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKStdAdasyn.drop('class', axis=1)
y = dfPKStdAdasyn['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKStdAdasyn.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK Std Adasyn.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 0.1, 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7450331125827815
# Accuracy test: 0.6973684210526315
# Best parameters: {'lda__shrinkage': 0.1, 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                          14
# split0_test_score  0.774194
# split1_test_score  0.677419
# split2_test_score  0.833333
# split3_test_score       0.7
# split4_test_score       0.6
# split5_test_score  0.766667
# split6_test_score  0.633333
# split7_test_score       0.8
# split8_test_score  0.733333
# split9_test_score       0.7
# Mean CV: 14    0.721828
# dtype: object
# Std CV: 14    0.073807
# dtype: object
# Model is pickled as model/try LDA PK Std Adasyn.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.70225806 0.70225806 0.70225806 0.70225806 0.70225806 0.70225806
#         nan        nan 0.70526882 0.70526882 0.70526882 0.70526882
#         nan        nan 0.72182796 0.72182796 0.72182796 0.72182796
#         nan        nan 0.70204301 0.70204301 0.70204301 0.70204301
#         nan        nan 0.68537634 0.68537634 0.68537634 0.68537634
#         nan        nan 0.68204301 0.68204301 0.68204301 0.68204301
#         nan        nan 0.68526882 0.68526882 0.68526882 0.68526882
#         nan        nan 0.68516129 0.68516129 0.68516129 0.68516129
#         nan        nan 0.69172043 0.69172043 0.69172043 0.69172043
#         nan        nan 0.6683871  0.6683871  0.6683871  0.6683871
#         nan        nan 0.65182796 0.65182796 0.65182796 0.65182796]
#   warnings.warn(

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKVarAdasyn.drop('class', axis=1)
y = dfPKVarAdasyn['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKVarAdasyn.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK Var Adasyn.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7251655629139073
# Accuracy test: 0.618421052631579
# Best parameters: {'lda__shrinkage': 'auto', 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                           8
# split0_test_score  0.774194
# split1_test_score  0.677419
# split2_test_score       0.8
# split3_test_score  0.633333
# split4_test_score       0.6
# split5_test_score  0.666667
# split6_test_score  0.666667
# split7_test_score       0.8
# split8_test_score  0.733333
# split9_test_score  0.633333
# Mean CV: 8    0.698495
# dtype: object
# Std CV: 8    0.073192
# dtype: object
# Model is pickled as model/try LDA PK Var Adasyn.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.66892473 0.66892473 0.66892473 0.66892473 0.66892473 0.66892473
#         nan        nan 0.69849462 0.69849462 0.69849462 0.69849462
#         nan        nan 0.67526882 0.67526882 0.67526882 0.67526882
#         nan        nan 0.67204301 0.67204301 0.67204301 0.67204301
#         nan        nan 0.65537634 0.65537634 0.65537634 0.65537634
#         nan        nan 0.63204301 0.63204301 0.63204301 0.63204301
#         nan        nan 0.64537634 0.64537634 0.64537634 0.64537634
#         nan        nan 0.65193548 0.65193548 0.65193548 0.65193548
#         nan        nan 0.64526882 0.64526882 0.64526882 0.64526882
#         nan        nan 0.63537634 0.63537634 0.63537634 0.63537634
#         nan        nan 0.65182796 0.65182796 0.65182796 0.65182796]
#   warnings.warn(

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.model_selection import GridSearchCV

# Memisahkan fitur dan class
X = dfPKAllAdasyn.drop('class', axis=1)
y = dfPKAllAdasyn['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape


# Definisikan preprocessor
preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2, scaling='normalize'), dfPKAllAdasyn.drop(columns='class').columns)
])

# Buat pipeline dengan LDA
pipeline = Pipeline([
    ('prep', preprocessor),
    ('lda', LinearDiscriminantAnalysis())
])

# Tentukan parameter grid untuk pencarian grid
parameter = {
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'lda__solver': ['svd', 'lsqr', 'eigen'],
    'lda__shrinkage': [None, 'auto'] + [x/10.0 for x in range(1, 10)]  # shrinkage hanya untuk lsqr dan eigen
}

# Buat objek GridSearchCV
model = GridSearchCV(pipeline, parameter, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='try LDA PK All Adasyn.pkl')
# Out:
# Fitting 10 folds for each of 66 candidates, totalling 660 fits
# {'lda__shrinkage': 0.3, 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 0.7218543046357616
# Accuracy test: 0.631578947368421
# Best parameters: {'lda__shrinkage': 0.3, 'lda__solver': 'lsqr', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                          26
# split0_test_score  0.870968
# split1_test_score  0.741935
# split2_test_score  0.866667
# split3_test_score  0.633333
# split4_test_score  0.566667
# split5_test_score  0.633333
# split6_test_score  0.633333
# split7_test_score  0.733333
# split8_test_score       0.7
# split9_test_score  0.633333
# Mean CV: 26    0.70129
# dtype: object
# Std CV: 26    0.102965
# dtype: object
# Model is pickled as model/try LDA PK All Adasyn.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 200 fits failed out of a total of 660.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\pipeline.py", line 405, in fit
#     self._final_estimator.fit(Xt, y, **fit_params_last_step)
#   File "c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\discriminant_analysis.py", line 615, in fit
#     raise NotImplementedError("shrinkage not supported with 'svd' solver.")
# NotImplementedError: shrinkage not supported with 'svd' solver.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.6788172  0.6788172  0.6788172  0.6788172  0.6788172  0.6788172
#         nan        nan 0.66526882 0.66526882 0.66526882 0.66526882
#         nan        nan 0.6883871  0.6883871  0.6883871  0.6883871
#         nan        nan 0.69172043 0.69172043 0.69172043 0.69172043
#         nan        nan 0.70129032 0.70129032 0.70129032 0.70129032
#         nan        nan 0.69483871 0.69483871 0.69483871 0.69483871
#         nan        nan 0.69494624 0.69494624 0.69494624 0.69494624
#         nan        nan 0.68516129 0.68516129 0.68516129 0.68516129
#         nan        nan 0.68494624 0.68494624 0.68494624 0.68494624
#         nan        nan 0.6816129  0.6816129  0.6816129  0.6816129
#         nan        nan 0.66827957 0.66827957 0.66827957 0.66827957]
#   warnings.warn(

# %% [markdown]
# LDA Ploting

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn.preprocessing import StandardScaler

# Memisahkan fitur dan class
X = dfVBKAllSmote.drop('class', axis=1)
y = dfVBKAllSmote['class']

lda = LDA(n_components=2)
X_R = lda.fit_transform(X, y)

from pylab import *

colors = ['maroon','royalblue','deeppink','red',  'mediumorchid', 'tan', 'forestgreen', 'olive', 'goldenrod', 'lightcyan', 'navy']
vectorizer = np.vectorize(lambda x: colors[x % len(colors)])
subplot(1,1,1)
plt.scatter(X_R[:,0],X_R[:,1],c=vectorizer(y))

# %% [markdown]
# Modeling

# %%
from sklearn.svm import SVC

X = dfPKMeanSmote.drop(columns="class")
y = dfPKMeanSmote['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape    

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2,scaling='maxabs'), dfPKMeanSmote.drop(columns='class').columns)
])
pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', SVC(max_iter=500))
])

from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp

parameter={
    'prep__numeric__poly__degree': [1],
    'prep__numeric__poly__interaction_only': [True, False],
    'algo__gamma': ([1,1.1,1.2,0.9,0.8]),
    'algo__C': ([100,99,98,101,102]),
 }

model = GridSearchCV(pipeline,gsp.svm_poly_params, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='SVM PK Mean Smote.pkl')
# Out:
# Fitting 10 folds for each of 294 candidates, totalling 2940 fits
# {'algo__C': 10.0, 'algo__gamma': 100.0, 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 1.0
# Accuracy test: 0.8536585365853658
# Best parameters: {'algo__C': 10.0, 'algo__gamma': 100.0, 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                         198
# split0_test_score   0.69697
# split1_test_score  0.818182
# split2_test_score  0.787879
# split3_test_score  0.848485
# split4_test_score  0.909091
# split5_test_score  0.909091
# split6_test_score   0.90625
# split7_test_score   0.90625
# split8_test_score   0.84375
# split9_test_score   0.84375
# Mean CV: 198    0.84697
# dtype: object
# Std CV: 198    0.067979
# dtype: object
# Model is pickled as model/SVM PK Mean Smote.pkl
# c:\Users\Acer\miniconda3\envs\env1\lib\site-packages\sklearn\svm\_base.py:299: ConvergenceWarning: Solver terminated early (max_iter=500).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %%
from sklearn.neighbors import KNeighborsClassifier

X = dfPKMeanSmote.drop(columns="class")
y = dfPKMeanSmote['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape    

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2,scaling='robust'), dfPKMeanSmote.drop(columns='class').columns)
])

pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', KNeighborsClassifier())
])
from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp


model = GridSearchCV(pipeline, gsp.knn_poly_params, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='KNN PK Mean Smote.pkl')
# Out:
# Fitting 10 folds for each of 540 candidates, totalling 5400 fits
# {'algo__n_neighbors': 1, 'algo__p': 2, 'algo__weights': 'uniform', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# Accuracy train: 1.0
# Accuracy test: 0.8902439024390244
# Best parameters: {'algo__n_neighbors': 1, 'algo__p': 2, 'algo__weights': 'uniform', 'prep__numeric__poly__degree': 1, 'prep__numeric__poly__interaction_only': True}
# 10 fold accuracy:
#                          24
# split0_test_score  0.757576
# split1_test_score  0.909091
# split2_test_score  0.818182
# split3_test_score  0.909091
# split4_test_score  0.909091
# split5_test_score  0.878788
# split6_test_score    0.9375
# split7_test_score    0.9375
# split8_test_score   0.78125
# split9_test_score   0.90625
# Mean CV: 24    0.874432
# dtype: object
# Std CV: 24    0.065058
# dtype: object
# Model is pickled as model/KNN PK Mean Smote.pkl

# %%
from sklearn.linear_model import LogisticRegression

X = dfPKMeanSmote.drop(columns="class")
y = dfPKMeanSmote['class']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)
X_train.shape, X_test.shape, y_train.shape, y_test.shape    

preprocessor = ColumnTransformer([
    ('numeric', num_pipe(poly=2,scaling='robust'), dfPKMeanSmote.drop(columns='class').columns)
])

pipeline = Pipeline([
    ('prep', preprocessor),
    ('algo', LogisticRegression(solver='lbfgs', n_jobs=-1, random_state=42)),
])

from sklearn.model_selection import GridSearchCV
from jcopml.tuning import grid_search_params as gsp


model = GridSearchCV(pipeline, gsp.logreg_poly_params, cv=10, n_jobs=-1, verbose=1)
model.fit(X_train, y_train)

evaluate(model, X_train, y_train, X_test, y_test)
save_model(model=model,file_name='LogReg PK Mean Smote.pkl')
# Out:
# Fitting 10 folds for each of 84 candidates, totalling 840 fits
# {'algo__C': 1000.0, 'algo__fit_intercept': True, 'prep__numeric__poly__degree': 3, 'prep__numeric__poly__interaction_only': False}
# Accuracy train: 0.843558282208589
# Accuracy test: 0.7439024390243902
# Best parameters: {'algo__C': 1000.0, 'algo__fit_intercept': True, 'prep__numeric__poly__degree': 3, 'prep__numeric__poly__interaction_only': False}
# 10 fold accuracy:
#                          77
# split0_test_score  0.787879
# split1_test_score  0.757576
# split2_test_score  0.757576
# split3_test_score  0.757576
# split4_test_score  0.757576
# split5_test_score  0.848485
# split6_test_score    0.8125
# split7_test_score    0.6875
# split8_test_score   0.84375
# split9_test_score    0.9375
# Mean CV: 77    0.794792
# dtype: object
# Std CV: 77    0.069168
# dtype: object
# Model is pickled as model/LogReg PK Mean Smote.pkl
